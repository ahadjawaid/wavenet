# %%
from model import WaveNet

# %%
res_layers = 8
res_blocks = 2
casual_layers = 1
kernal_size = 7

model = WaveNet(res_layers, res_blocks, casual_layers, kernal_size=kernal_size)

# %%
model.loadState("model_checkpoints/2_checkpoint.pt")

# %%
from data import AudioMP3Dataset, collate_fn

# %%
dataset = AudioMP3Dataset("piano_music/")

# %%
from torch.utils.data import DataLoader

# %%
item = dataset[0]

# %%
waveform, sample_rate = item
clipped_file = waveform[:100000]
clipped_file.shape
# Out:
# torch.Size([100000])

# %%
import IPython

# %%
IPython.display.Audio(data=clipped_file, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
model.generate(clipped_file.view(1,1,-1), 100000)
# Out:
# [W NNPACK.cpp:53] Could not initialize NNPACK! Reason: Unsupported hardware.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 model.generate(clipped_file.view(1,1,-1), 100000)
#
# File ~/programming/ml/torch/speech/wavenet/model.py:76, in WaveNet.generate(self, inputs, time_steps)
#      74     category = torch.argmax(prob, dim=0)
#      75     pred = decodeMuLaw(category)
# ---> 76     x = torch.cat((x, pred.view(1,1,1)), dim=2)
#      78 return x
#
# RuntimeError: shape '[1, 1, 1]' is invalid for input of size 256

# %%
import torch
from preprocess import decodeMuLaw

time_steps = 100000
inputs = clipped_file.view(1,1,-1)

x = inputs
for i in range(time_steps):
    if i % 100 == 0: 
        print(i)
    prob = model.forward(x)
    category = torch.argmax(prob, dim=1)
    pred = decodeMuLaw(category)
    x = torch.cat((x, pred.view(1,1,-1)), dim=2)
# Out:
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [38], in <cell line: 8>()
#       9 if i % 100 == 0:
#      10     print(i)
# ---> 11 prob = model.forward(x)
#      12 category = torch.argmax(prob, dim=1)
#      13 pred = decodeMuLaw(category)
#
# File ~/programming/ml/torch/speech/wavenet/model.py:41, in WaveNet.forward(self, inputs, local_inputs, global_inputs)
#      39 skip_connections = []
#      40 for residual_layer in self.residual_blocks:
# ---> 41     residual_out, skip_out = residual_layer(residual_out, local_inputs, global_inputs)
#      42     skip_connections.append(skip_out)
#      44 skip_connections = list(map(lambda skip: skip[:,:,-skip_connections[-1].size(2)], skip_connections))
#
# File ~/opt/anaconda3/envs/torchenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
# ...
